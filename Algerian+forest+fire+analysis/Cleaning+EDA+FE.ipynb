# %% [markdown]
# # CLEANING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# ### The index from 0 to 122 are Bejaija reion and after that its sidi-bel abbes region

# %%
#Data cleaning 
# df.isnull().sum()
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1
df["Region"] = df["Region"].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
#removing null values
df=df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.loc[121:124]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC   DC  ISI  BUI  \
# 121   30     09  2012           25   78   14    1.4    45  1.9  7.5  0.2  2.4
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC   DC  ISI  BUI
# 123   01     06  2012           32   71   12    0.7  57.1  2.5  8.2  0.6  2.8
# 124   02     06  2012           30   73   13      4  55.7  2.7  7.8  0.6  2.9
#
#      FWI    Classes    Region
# 121  0.1  not fire          0
# 122  FWI    Classes         1
# 123  0.2  not fire          1
# 124  0.2  not fire          1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
#fix extra spaces in the column names
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#CHANGES THE REQUIREDS COLUMNS AS INTEGER DATATYPES/FLOAT
df[['day', 'month', 'year','Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year','Temperature', 'RH', 'Ws']].astype(int)

# %%
df.dtypes
# Out:
# day             int32
# month           int32
# year            int32
# Temperature     int32
# RH              int32
# Ws              int32
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region          int32
# dtype: object

# %%
objects=[features for features in df.columns if df[features].dtype==object]
for i in objects:
    if i != "Classes": # except classes
        df[i]=df[i].astype(float)

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region           int32
# dtype: object

# %% [markdown]
# # EDA & Feature Engineering

# %%
#Let save the cleaneed dataset
df.to_csv("Algerian_forest_fires__cleaned_dataset.csv",index=False)

# %%
#EDA
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df_copy=df.drop(['day','month','year'],axis=1) #axis=0 mean down thew row and =1 mean across the columns

# %%
#Encoding of categories in classes
df_copy['Classes']=np.where(df_copy['Classes']==('not fire'),0,1)
df['Classes']=np.where(df['Classes']==('not fire'),0,1)

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    241
# 0      2
# Name: count, dtype: int64

# %%
#plot destiny plot for all features
plt.style.use('seaborn-v0_8')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
#percentage for pie chart
percentage=df_copy["Classes"].value_counts(normalize=True)*100
percentage
# Out:
# Classes
# 1    99.176955
# 0     0.823045
# Name: proportion, dtype: float64

# %%
#plotting piechart
classlabels=['fire','not fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title('Pe chart of classes')
plt.show()

# %%
#corr()
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.179959 -0.129027 -0.081375 -0.578144  0.231193  0.073516
# ...

# %%
sns.heatmap(df_copy.corr(),annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %%
#monthly fire analysis
df_temp = df.loc[df['Region'] == 1]
plt.figure(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes', data=df_temp)
plt.title('Sidi-Bel Abbes Region')
plt.show()

# %%
df_temp = df.loc[df['Region'] == 0]
plt.figure(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes', data=df_temp)
plt.title('Bejaju Region')
plt.show()
